# %% [markdown]
# \begin{array}{|c|c|c|c|l|}
# \hline
# \textbf{Gate} & \textbf{Boolean Notation} & \textbf{Alt Notation} & \textbf{ASCII Code} & \textbf{Meaning / Condition} \\
# \hline
# \text{NOT}  & \bar{A}           & \neg A \text{ or } A' & \text{NOT}(A)   & \text{Inverts input signal} \\
# \text{AND}  & A \cdot B         & A \wedge B \text{ or } AB & A \text{ AND } B & \text{TRUE if both are TRUE} \\
# \text{OR}   & A + B             & A \vee B              & A \text{ OR } B  & \text{TRUE if at least 1 is TRUE} \\
# \text{XOR}  & A \oplus B        & A \oplus_2 B          & A \text{ XOR } B & \text{TRUE if inputs differ} \\
# \text{NAND} & \overline{A \cdot B} & \neg(A \cdot B)    & A \text{ NAND } B & \text{FALSE only if both are TRUE} \\
# \text{NOR}  & \overline{A + B}  & \neg(A + B)           & A \text{ NOR } B & \text{TRUE only if both are FALSE} \\
# \text{XNOR} & A \odot B         & \neg(A \oplus B)      & A \text{ XNOR } B & \text{TRUE if inputs match} \\
# \hline
# \end{array}
